# %% [markdown]
# <a href="https://colab.research.google.com/github/jxhnv/Analisis_de_Estadisticas/blob/main/Analisis_Encuesta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #** ANALISIS ESTADISTICOS DE LA ENCUESTA DE REQUERIMIENTOS, CON VALORES CERRADOS, DE UNA MUESTRA DE POBLACIÓN **

# %% [markdown]
# # Cargar datos en excel o CSV #

# %%
from google.colab import files
uploaded = files.upload () # ESTE ES PARA QUE SE EJECUTE EN UNA VENTANA#
# Out:
#      <input type="file" id="files-d8ce9d8d-e8f0-42f1-bb5f-174fb37005f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d8ce9d8d-e8f0-42f1-bb5f-174fb37005f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Paso 1: CARGA, INSPECCION Y LIMPIEZA DE DATOS

# %% [markdown]
# Paso 1. Importar librerias

# %%
# PANDAS PARA TRABAJAR DATOS DE LA TABLA DEL EXCEL
import pandas as pd
# numpy para calcular numericos ( promedio, desviaciones, media, balanza)
import numpy as np
# matplolib y seaborn: para crear graficas
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Paso 2: Carga Archivo Excel
# Leer un archivo en excel y lo convierte en una tabla de python
# La tabla se llama DataFrame, el cual es una hoja de excel con filas y columnas.

# %%
# Nombre del archivo y pestaña a leer
nombre_archivo = 'Validacion_SaaS_Ecommerce_Dashboard.xlsx'
nombre_pestana = 'Respuestas_Encuesta'

# cargar archivos
df = pd.read_excel (nombre_archivo,sheet_name=nombre_pestana)
# verificar que se cargo los datos correctamente
print (f'archivos cargados: {df.shape[0]} filas y {df.shape[1]}')
# Out:
# archivos cargados: 30 filas y 20

# %% [markdown]
# # Paso 3: Inspección de datos

# %% [markdown]
# ** ¿ Que es lo que hace? ** Muestra como se ven los datos y que tipo de información tiene, en ese caso la información de los requisitos tomados por parte de los clientes

# %%
# mostrar las primeras 10 filas
print ('mostras las 10 primeras filas')
df.head (10)
# Out:
# mostras las 10 primeras filas
#    ID Comercio    Nombre Comercio Categoría / Sector Tamaño Inventario (SKUs)  \
# 0            1     Moda Urbana Co               Moda  Mediano (100-1000 SKUs)
# 1            2     TechZone Store         Tecnología      Grande (>1000 SKUs)
# 2            3     Glow Cosmetics            Belleza      Pequeño (<100 SKUs)
# 3            4       NutriOrganic          Alimentos  Mediano (100-1000 SKUs)
# 4            5     Hogar & Decora              Hogar      Grande (>1000 SKUs)
# 5            6     FitSport Store           Deportes  Mediano (100-1000 SKUs)
# 6            7     PetLovers Shop           Mascotas      Pequeño (<100 SKUs)
# 7            8    Kiddos Juguetes         Juguetería  Mediano (100-1000 SKUs)
# 8            9  BookWorm Librería           Librería      Grande (>1000 SKUs)
# 9           10  AutoParts Express         Automotriz      Grande (>1000 SKUs)
#
#                        Canales de Venta  P1_Abandono  \
# ...

# %%
# la otra forma es
print ('______________________________________________________')
display(df.dtypes)
# Out:
# ______________________________________________________
# ID Comercio                  int64
# Nombre Comercio             object
# Categoría / Sector          object
# Tamaño Inventario (SKUs)    object
# Canales de Venta            object
# P1_Abandono                 object
# P2_Impacto1Clic             object
# P3_PagoPref                 object
# P4_Autenticacion            object
# P5_Comision1Clic            object
# P6_NumCanales               object
# P7_FrecOverselling          object
# P8_TiempoActualizacion      object
# P9_Centralizacion           object
# P10_TemorSinc               object
# P11_VentasRecurrentes       object
# P12_Suscripciones           object
# P13_FuncionalidadUpsell     object
# P14_AumentoTicket           object
# P15_PrecioSaaS              object
# dtype: object

# %% [markdown]
# # Paso 4: Buscar Problemas de los Datos
# Buscar problemas en los datos:
# 1. Valores nulos
# 2. celdas vacias
# 3. filas duplicadas

# %%
# contar valores nulos por columna
print ("valores nulos por columna: ")
nulos= df.isnull ().sum()
print ('cantidad de nulos son: ', nulos)
# Out:
# valores nulos por columna:
# cantidad de nulos son:  ID Comercio                 0
# Nombre Comercio             0
# Categoría / Sector          0
# Tamaño Inventario (SKUs)    0
# Canales de Venta            0
# P1_Abandono                 0
# P2_Impacto1Clic             0
# P3_PagoPref                 0
# P4_Autenticacion            0
# P5_Comision1Clic            0
# P6_NumCanales               0
# P7_FrecOverselling          0
# P8_TiempoActualizacion      0
# P9_Centralizacion           0
# P10_TemorSinc               0
# P11_VentasRecurrentes       0
# P12_Suscripciones           0
# P13_FuncionalidadUpsell     0
# P14_AumentoTicket           0
# P15_PrecioSaaS              0
# dtype: int64

# %%
# contar filas duplicadas
duplicados = df.duplicated().sum()
print ("filas duplicadas: ", duplicados)
# Out:
# filas duplicadas:  0

# %% [markdown]
# # OBSERVACIÓN IMPORTANTE.
# 1. Si una columna tiene muchos nulos >50%, esta muestra no serviria.
# 2. Si es inferior de 50%, se puede trabajar la muestra.

# %% [markdown]
# # Paso 5: Limpiar los datos
# Elimina espacios de mas al inicio y final de cada texto. EJEMPLO " MODA " Se convierte en "MODA". Esto es necesario porque si tiene espacios, estas palabras no son iguales.

# %%
#Seleccionar columnas de Texto
columnas_texto = df.select_dtypes (include='object'). columns
#limpiar cada columna
for columna in columnas_texto:
   df[columna] = df[columna].astype(str).str.strip()
#mostrar resultado de la limpieza que fue completada
print ('limpieza completada')
# Out:
# limpieza completada

# %% [markdown]
# # ESTADISTICA DESCRIPTIVA
# La estadística descriptiva es la rama de la estadística que se encarga de recolectar, organizar, resumir, analizar y presentar un conjunto de datos numéricos o cualitativos mediante tablas, gráficos y medidas de resumen.
# Su objetivo principal es describir y caracterizar el comportamiento de los datos sin realizar inferencias o generalizaciones sobre una población mayor.

# %% [markdown]
# # HERRAMIENTAS PRINCIPALES
# Medidas de Tendencia Central: Indican el valor alrededor del cual se agrupan los datos.
# Media: El promedio aritmético.
# Mediana: El valor central cuando los datos están ordenados.
# Moda: El valor que más se repite.
#
# Medidas de Dispersión: Muestran qué tan alejados o dispersos están los datos respecto a la media.
# Rango, Varianza, Desviación Estándar y Coeficiente de Variación.
#
# Medidas de Posición: Dividen un conjunto de datos ordenados en partes iguales.
# Cuartiles, Deciles y Percentiles.
#
# Representación Gráfica: Formas visuales para interpretar la información de manera rápida.
# Histogramas, diagramas de barras, diagramas de sectores (pastel), diagramas de caja y bigotes.

# %% [markdown]
# # Punto 6: Distribución por sector

# %% [markdown]
# **¿Que hace?** Cuenta cuantos comercios hay en cada sector y calcula el porcentaje

# %%
#value_conts() Cuenta las veces que aparece cada valor
# normalize = True lo convierte en porcentaje
tabla_sector =pd.DataFrame({'Cantidad' : df['Categoría / Sector'].value_counts(),'Porcentaje (%)' : (df['Categoría / Sector'].value_counts(normalize=True)*100).round(2)})

print ("Distribucion por sector")
display (tabla_sector)
# Out:
# Distribucion por sector
#                     Cantidad  Porcentaje (%)
# Categoría / Sector
# Moda                       4           13.33
# Tecnología                 4           13.33
# Belleza                    4           13.33
# Alimentos                  4           13.33
# Hogar                      4           13.33
# Deportes                   2            6.67
# Mascotas                   2            6.67
# Juguetería                 2            6.67
# Librería                   2            6.67
# Automotriz                 2            6.67

# %% [markdown]
# # Paso 7: Tablas Cruzadas

# %% [markdown]
# **¿Que hace?** Muestra la relación entre dos variables. Ejemplo. ¿Que sectores estan dispuestos a pagar más?

# %%
# pd.crosstab() Crea una tabla que cruza dos variables
# las filas son sectores, las columnas son rangos de precio
crosstab =pd.crosstab(df['Categoría / Sector'],df['P15_PrecioSaaS'],margins=True)
print("Tabla cruzada vr precio por sector")
display (crosstab)
# Out:
# Tabla cruzada vr precio por sector
# P15_PrecioSaaS      $100 - $199 USD/mes  $49 - $99 USD/mes  < $49 USD/mes  \
# Categoría / Sector
# Alimentos                             3                  1              0
# Automotriz                            0                  0              0
# Belleza                               2                  2              0
# Deportes                              1                  1              0
# Hogar                                 1                  1              1
# Juguetería                            0                  1              1
# Librería                              0                  1              1
# Mascotas                              0                  2              0
# Moda                                  2                  1              0
# Tecnología                            4                  0              0
# All                                  13                 10              3
#
# ...

# %% [markdown]
# # Paso 8: KPIs Indicadores clave

# %% [markdown]
# **¿Que hace?** Calcula porcentajes importantes para el negocio. Ejemplo. ¿Cuantos clientes pago 1-click?

# %%
# Kpi 1 : % que considera alto en impacto de pago 1-Click
# str.contains () busca texto, .mean () calcula promedio, * 100 convierte a %
kpi1 = df['P2_Impacto1Clic'].str.contains('Alto|Crítico', case=False, na=False).mean()*100
# KPI 2: % con problemas de overselling frecuente
kpi2= df['P7_FrecOverselling'].str.contains('Frecuentemente|Diariamente', case=False, na=False). mean()*100
print (f"KPI 1: Impacto 1_click alto|Crítico= {kpi1:.2f}%")
print (f"KPI 2: Overselling Frecuente|Díario= {kpi2:.2f}%")
# Out:
# KPI 1: Impacto 1_click alto|Crítico= 76.67%
# KPI 2: Overselling Frecuente|Díario= 56.67%

# %% [markdown]
# # Paso 9: Mapeo de texto a Numeros

# %% [markdown]
# **¿Que hace?** Convierte respuesta de texto a numeros para poder hacer calculo. Ejemplo: '3 - 4 Canales' se convierte en 3.5

# %%
# Diccionario de conversiones
mapa_canales = {'1 canal': 1.0, '2 canales': 2.0, '3-4 canales': 3.5, '5 o más canales': 5.0}
# aplicar las conversiones
df['NumCanales_Num'] = df['P6_NumCanales'].map(mapa_canales)
#Calcular estadisticas
print (f"Promedio de canales: {df['NumCanales_Num'].mean():.2f}")
print (f"Mediana de canales: {df['NumCanales_Num'].median():.2f}")
# Out:
# Promedio de canales: 2.65
# Mediana de canales: 2.00

# %% [markdown]
# # Paso 10: Método de pago por sector

# %% [markdown]
# ¿Que hace? Para cada sector, encuentra cual es el método de pago más elegido.
# 1. Función para obtener la moda de la forma segura
# 2. La "moda" es el valor que más se repite

# %%
def moda_segura(x):
  m=x.mode()
  return m.iloc[0] if not m.empty else 'sin datos'

# agrupar pro sector y encontrar el método  mas usado
pago_por_sector= df.groupby('Categoría / Sector')['P3_PagoPref'].agg(moda_segura)
print("Método de pago mas usado por sector:")
print(pago_por_sector)
# Out:
# Método de pago mas usado por sector:
# Categoría / Sector
# Alimentos     Tarjeta de crédito/débito guardada
# Automotriz    Tarjeta de crédito/débito guardada
# Belleza       Tarjeta de crédito/débito guardada
# Deportes                    Billeteras digitales
# Hogar         Tarjeta de crédito/débito guardada
# Juguetería                   Transferencia / PSE
# Librería      Tarjeta de crédito/débito guardada
# Mascotas                    Billeteras digitales
# Moda          Tarjeta de crédito/débito guardada
# Tecnología                  Billeteras digitales
# Name: P3_PagoPref, dtype: object

# %% [markdown]
# # Paso 11: Disposición a pagar comisión

# %% [markdown]
# ¿Que hace? Muestra qué porcentaje de comisión aceptaria pagar una comisión extra del 0.5%.

# %%
# value_count (normalize= True) calcula proporciones
comision_dist= df['P5_Comision1Clic'].value_counts(normalize=True)
print ("¿Cuantos aceptaria pagar comisión del 0.5%")
for respuesta, porcentaje in comision_dist.items():
  print (f"{respuesta}:{porcentaje:.1f}%")
# Out:
# ¿Cuantos aceptaria pagar comisión del 0.5%
# Sí, si aumenta conversión >10%:0.4%
# Tal vez, según volumen:0.3%
# Definitivamente sí:0.3%
# Definitivamente no:0.1%

# %% [markdown]
# # Paso 12: Visualización de Datos

# %% [markdown]
# Apartir de este son 4 puntos donde vamos a estar graficando
# **¿Por que graficar?** Una imagen vale más que 1000 números. Las gráficas nos ayudan a ver patrones, comparar grupos facilmente y comunicar resultados a otros

# %% [markdown]
# # Paso 12.1 Graficas de barras horizontales

# %% [markdown]
# **¿Que muestra?** Se usan barras horizontales porque los nombres son largos.

# %%
plt.figure(figsize=(10,5))
# contar cuantos eligieron cada funcionalidad
upsell_counts = df['P13_FuncionalidadUpsell'].value_counts()
# crear barras horizontales
sns.barplot(x=upsell_counts.values,y=upsell_counts.index,palette='viridis')
#colocación de titulos para el diagrama
plt.title('¿Que funcionalidades del UPsell son más demandadas?')
plt.xlabel('Número de comercio')
plt.ylabel('Funcionalidad')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1852/562297938.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=upsell_counts.values,y=upsell_counts.index,palette='viridis')

# %% [markdown]
# # Paso 12.2: Gráfico Circular (Pie Chart)

# %% [markdown]
# **¿Que muestra?**
# Cuanto esta dispuesto a pagar los comercios?
# Se usa circular porque muestra parte de un todo (Porcentajes).

# %%
plt.figure(figsize=(7,7))
# Calcular el porcentaje de cada
# Contar respuestas de precio
p_counts= df ['P15_PrecioSaaS'].value_counts()
# Contar respuestas de precio
p_counts= df['P15_PrecioSaaS'].value_counts()
# Colores y explosión
colors= ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b']
colors= colors[:len(p_counts)]
explode = [0.08 if i == 0 else 0 for i in range (len(p_counts))]
# Crear el grafico circular
plt.pie (p_counts,labels=p_counts.index, autopct = '%1.1f%%', startangle= 140, colors = colors, explode= explode)
plt.title ('¿Cuantos estan dispuestos a pagar mensualmente?')
plt.tight_layout()
plt.show ()
